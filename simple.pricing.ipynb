# %%
#imports 
import yfinance as yf
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
#define tickers
commodity_tickers = {
    'Sugar': 'SB=F',
    'Coffee': 'KC=F',
    'Cocoa': 'CC=F',
    'Cotton': 'CT=F',
    'Wheat': 'ZW=F',
    'Corn': 'ZC=F',
    'Soybeans': 'ZS=F',
    'DXY': 'DX-Y.NYB',
}

#for loop for tickers
commodity_data = {}
for name, ticker in commodity_tickers.items():
    commodity_data[name] = yf.Ticker(ticker).history(period="10y")['Close']
#convert to dataframe
df_commodities = pd.DataFrame(commodity_data)

print(df_commodities.head())
display(df_commodities.shape)
# Out:
#                                Sugar      Coffee   Cocoa     Cotton   Wheat  \
# Date
# 2016-07-05 00:00:00-04:00  20.870001  144.199997  3104.0  63.750000  419.50
# 2016-07-06 00:00:00-04:00  20.570000  141.949997  3119.0  63.779999  415.75
# 2016-07-07 00:00:00-04:00  19.730000  140.449997  3149.0  63.669998  412.00
# 2016-07-08 00:00:00-04:00  19.570000  142.750000  3136.0  65.919998  420.75
# 2016-07-11 00:00:00-04:00  20.280001  147.949997  3138.0  68.139999  416.25
#
#                              Corn  Soybeans        DXY
# Date
# 2016-07-05 00:00:00-04:00  344.00   1117.00  96.169998
# 2016-07-06 00:00:00-04:00  335.75   1106.25  96.059998
# 2016-07-07 00:00:00-04:00  335.50   1054.25  96.330002
# 2016-07-08 00:00:00-04:00  349.75   1089.75  96.300003
# 2016-07-11 00:00:00-04:00  343.75   1082.75  96.570000
# (2516, 8)

# %%
#visualise the results
plt.figure(figsize=(14, 7))
plt.plot(df_commodities)
plt.title('Ags v DXY 10 year')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(df_commodities.columns)
plt.show()
